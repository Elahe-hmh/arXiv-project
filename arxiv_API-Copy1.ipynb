# %%
import urllib.request as libreq
import pandas as pd
import json

# %%
with libreq.urlopen('http://export.arxiv.org/api/query?search_query=all:astro-ph&sortBy=submittedDate&sortOrder=descending&start=0&max_results=3') as url:
    r = url.read()
print(r)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dall%3Aastro-ph%26id_list%3D%26start%3D0%26max_results%3D3" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=all:astro-ph&amp;id_list=&amp;start=0&amp;max_results=3</title>\n  <id>http://arxiv.org/api/KA0uW6zVamMRhIRvpykAXHvOAic</id>\n  <updated>2020-03-17T00:00:00-04:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">105383</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">3</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/1912.12092v1</id>\n    <updated>2019-12-27T13:35:35Z</updated>\n    <published>2019-12-27T13:35:35Z</published>\n    <title>Bremsstrahlung emission from nucl
# ...

# %%
s= r.decode("utf-8")
#type(s)
print(s)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom">
#   <link href="http://arxiv.org/api/query?search_query%3Dall%3Aastro-ph%26id_list%3D%26start%3D0%26max_results%3D3" rel="self" type="application/atom+xml"/>
#   <title type="html">ArXiv Query: search_query=all:astro-ph&amp;id_list=&amp;start=0&amp;max_results=3</title>
#   <id>http://arxiv.org/api/KA0uW6zVamMRhIRvpykAXHvOAic</id>
#   <updated>2020-03-17T00:00:00-04:00</updated>
#   <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">105383</opensearch:totalResults>
#   <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>
#   <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">3</opensearch:itemsPerPage>
#   <entry>
#     <id>http://arxiv.org/abs/1912.12092v1</id>
#     <updated>2019-12-27T13:35:35Z</updated>
#     <published>2019-12-27T13:35:35Z</published>
# ...

# %%
my_json = r.decode('utf8').replace("'", '"')
j=my_json
type(my_json)
print(my_json)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom">
#   <link href="http://arxiv.org/api/query?search_query%3Dall%3Aastro-ph%26id_list%3D%26start%3D0%26max_results%3D3" rel="self" type="application/atom+xml"/>
#   <title type="html">ArXiv Query: search_query=all:astro-ph&amp;id_list=&amp;start=0&amp;max_results=3</title>
#   <id>http://arxiv.org/api/KA0uW6zVamMRhIRvpykAXHvOAic</id>
#   <updated>2020-03-17T00:00:00-04:00</updated>
#   <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">105383</opensearch:totalResults>
#   <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>
#   <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">3</opensearch:itemsPerPage>
#   <entry>
#     <id>http://arxiv.org/abs/1912.12092v1</id>
#     <updated>2019-12-27T13:35:35Z</updated>
#     <published>2019-12-27T13:35:35Z</published>
# ...

# %%
import re
sentence = j
word = "<updated>"
starts1=[]
ends1=[]
for match in re.finditer(word, sentence):
    print (match.start(), match.end())
    starts1.append(match.start())
    ends1.append(match.end())
starts1=starts1[1:]
ends1=ends1[1:]
print(starts,ends)
# Out:
# 411 420
# 851 860
# 3619 3628
# 6683 6692
# [857, 2983, 5607] [866, 2992, 5616]

# %%
sentence = j
word = "</updated>"
starts2=[]
ends2=[]
for match in re.finditer(word, sentence):
    print (match.start(), match.end())
    starts2.append(match.start())
    ends2.append(match.end())
starts2=starts2[1:]
ends2=ends2[1:]
print(starts2,ends2)
# Out:
# 445 455
# 880 890
# 3648 3658
# 6712 6722
# [880, 3648, 6712] [890, 3658, 6722]

# %%
E=[]
for i in range (len(starts1)):
    e=[]
    e.append(ends1[i])
    e.append(starts2[i])
    E.append(e)
print(E)
# Out:
# [[860, 880], [3628, 3648], [6692, 6712]]

# %%
publish_list=[]
for i in E:
    a=i[0]
    b=i[1]
    #print (j[a:b])
    publish_list.append(j[a:b])
print(publish_list)
# Out:
# ['2019-12-27T13:35:35Z', '2011-01-17T08:03:55Z', '2010-08-09T01:24:01Z']
