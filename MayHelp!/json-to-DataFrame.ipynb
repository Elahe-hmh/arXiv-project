# %%
import pandas as pd

# %%
path = input("Enter the path of the json file(example --> D:/Machine Learning/data.json) -->")
# Out:
# Enter the path of the json file(example --> D:/Machine Learning/data.json) -->C:/Users/asus/Desktop/xxx/merged.json

# %%
r = pd.read_json(path)

# %%
r
# Out:
#                        identifier   datestamp  setSpec               id  \
# 0         oai:arXiv.org:1105.6220  2016-01-01  physics        1105.6220
# 1         oai:arXiv.org:1109.5417  2016-01-01  physics        1109.5417
# 2         oai:arXiv.org:1210.4722  2016-01-01  physics        1210.4722
# 3         oai:arXiv.org:1301.4457  2016-01-01  physics        1301.4457
# 4         oai:arXiv.org:1312.6429  2016-01-01  physics        1312.6429
# ..                            ...         ...      ...              ...
# 70  oai:arXiv.org:physics/9911031  2016-01-01  physics  physics/9911031
# 71       oai:arXiv.org:1506.04386  2016-01-04  physics          1506.04
# 72       oai:arXiv.org:1511.07129  2016-01-04  physics          1511.07
# 73       oai:arXiv.org:1512.02855  2016-01-04  physics          1512.03
# 74       oai:arXiv.org:1512.08042  2016-01-03  physics          1512.08
#
#        created     updated                                            authors  \
# ...
